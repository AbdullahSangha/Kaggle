# %% [markdown]
# <a href="https://www.kaggle.com/code/abdullahsangha/it-s-all-about-life?scriptVersionId=114377748" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <center><img src="https://i.postimg.cc/ZbGGBMM2/I-m-dreaming-of-a.png"
#              style='border-radius:10px'></center>

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Loading Libraries</div>

# %%
import os
import warnings 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px
import plotly.io as pio

import colorama
from colorama import Fore, Style
warnings.simplefilter(action='ignore', category=FutureWarning)
print(Fore.MAGENTA + "All Libraries Imported Successfully!")
# Out:
# All Libraries Imported Successfully!

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Read Datasets</div>

# %%
life_exp_df = pd.read_csv("/kaggle/input/suicide-rate-and-life-expectancy/Life expectancy.csv")
suicidal_rate_df = pd.read_csv("/kaggle/input/suicide-rate-and-life-expectancy/Suicide Rate.csv")

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Explore Life Expectancy Dataset</div>

# %%
life_exp_df.head(5).style.background_gradient(cmap='Spectral') #We can use head, tail and sample to explore our dataset.
# Out:
# <style type="text/css">
# #T_0e099_row0_col1 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_0e099_row0_col2 {
#   background-color: #df4e4b;
#   color: #f1f1f1;
# }
# #T_0e099_row0_col3, #T_0e099_row3_col4, #T_0e099_row4_col1, #T_0e099_row4_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_0e099_row0_col4 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
# }
# #T_0e099_row1_col1 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_0e099_row1_col2 {
#   background-color: #5cb7aa;
#   color: #f1f1f1;
# }
# #T_0e099_row1_col3 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_0e099_row1_col4 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
# }
# #T_0e099_row2_col1 {
#   background-color: #cdeb9d;
#   color: #000000;
# }
# #T_0e099_row2_col2 {
#   background-color: #aedea3;
#   color: #000000;
# }
# #T_0e099_row2_col3 {
#   background-color: #edf8a3;
#   color: #000000;
# }
# #T_0e099_row2_col4 {
#   background-color: #fed884;
# ...

# %%
life_exp_df.sample(5).style.background_gradient(cmap='gist_earth_r') #We can use head, tail and sample to explore our dataset.
# Out:
# <style type="text/css">
# #T_bc416_row0_col1, #T_bc416_row0_col2, #T_bc416_row0_col3, #T_bc416_row1_col4, #T_bc416_row4_col4 {
#   background-color: #fdfbfb;
#   color: #000000;
# }
# #T_bc416_row0_col4, #T_bc416_row2_col1, #T_bc416_row2_col2, #T_bc416_row2_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bc416_row1_col1 {
#   background-color: #184179;
#   color: #f1f1f1;
# }
# #T_bc416_row1_col2 {
#   background-color: #090e75;
#   color: #f1f1f1;
# }
# #T_bc416_row1_col3 {
#   background-color: #24647c;
#   color: #f1f1f1;
# }
# #T_bc416_row2_col4 {
#   background-color: #dbb8a2;
#   color: #000000;
# }
# #T_bc416_row3_col1 {
#   background-color: #37886e;
#   color: #f1f1f1;
# }
# #T_bc416_row3_col2 {
#   background-color: #2d7a7f;
#   color: #f1f1f1;
# }
# #T_bc416_row3_col3 {
#   background-color: #398c67;
#   color: #f1f1f1;
# }
# #T_bc416_row3_col4 {
#   background-color: #c3a46c;
#   color: #f1f1f1;
# }
# #T_bc416_row4_col1 {
#   background-color: #060574;
# ...

# %%
# Null Value Percentage Per column
percent_missing = life_exp_df.isnull().sum() * 100 / len(life_exp_df)
missing_value_df = pd.DataFrame({'column_name': life_exp_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending=False).style.background_gradient(cmap='Accent')
# Out:
# <style type="text/css">
# #T_99f8b_row0_col1, #T_99f8b_row1_col1, #T_99f8b_row2_col1, #T_99f8b_row3_col1, #T_99f8b_row4_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# </style>
# <table id="T_99f8b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >column_name</th>
#       <th class="col_heading level0 col1" >percent_missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f8b_level0_row0" class="row_heading level0 row0" >Country</th>
#       <td id="T_99f8b_row0_col0" class="data row0 col0" >Country</td>
#       <td id="T_99f8b_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_99f8b_level0_row1" class="row_heading level0 row1" >Life Expectancy (years) - Men</th>
#       <td id="T_99f8b_row1_col0" class="data row1 col0" >Life Expectancy (years) - Men</td>
#       <td id="T_99f8b_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
# ...

# %%
life_exp_df.dtypes
# Out:
# Country                               object
# Life Expectancy (years) - Men        float64
# Life Expectancy (years) - Women      float64
# Happiness Score                      float64
# Fertility Rate (births per woman)    float64
# dtype: object

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Explore Suicides Dataset</div>

# %%
suicidal_rate_df.head(5).style.background_gradient(cmap='Spectral') #We can use head, tail and sample to explore our dataset.
# Out:
# <style type="text/css">
# #T_44baa_row0_col2 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_44baa_row1_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_44baa_row2_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_44baa_row3_col2 {
#   background-color: #f36b43;
#   color: #f1f1f1;
# }
# #T_44baa_row4_col2 {
#   background-color: #fca85e;
#   color: #000000;
# }
# </style>
# <table id="T_44baa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >GDP per capita</th>
#       <th class="col_heading level0 col2" >Suicide rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44baa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44baa_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_44baa_row0_col1" class="data row0 col1" >1,105</td>
# ...

# %%
suicidal_rate_df.tail(5).style.background_gradient(cmap='Spectral') #We can use head, tail and sample to explore our dataset.
# Out:
# <style type="text/css">
# #T_af97d_row0_col2 {
#   background-color: #ab0f45;
#   color: #f1f1f1;
# }
# #T_af97d_row1_col2 {
#   background-color: #d7414e;
#   color: #f1f1f1;
# }
# #T_af97d_row2_col2 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# #T_af97d_row3_col2 {
#   background-color: #eb6046;
#   color: #f1f1f1;
# }
# #T_af97d_row4_col2 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af97d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Country</th>
#       <th class="col_heading level0 col1" >GDP per capita</th>
#       <th class="col_heading level0 col2" >Suicide rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af97d_level0_row0" class="row_heading level0 row0" >135</th>
#       <td id="T_af97d_row0_col0" class="data row0 col0" >Spain</td>
#       <td id="T_af97d_row0_col1" class="data row0 col1" >29,542</td>
# ...

# %%
# Null Value Percentage Per column
percent_missing = suicidal_rate_df.isnull().sum() * 100 / len(suicidal_rate_df)
missing_value_df = pd.DataFrame({'column_name': suicidal_rate_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', ascending=False).style.background_gradient(cmap='Accent')
# Out:
# <style type="text/css">
# #T_7a1c7_row0_col1, #T_7a1c7_row1_col1, #T_7a1c7_row2_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# </style>
# <table id="T_7a1c7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >column_name</th>
#       <th class="col_heading level0 col1" >percent_missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a1c7_level0_row0" class="row_heading level0 row0" >Country</th>
#       <td id="T_7a1c7_row0_col0" class="data row0 col0" >Country</td>
#       <td id="T_7a1c7_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7a1c7_level0_row1" class="row_heading level0 row1" >GDP per capita</th>
#       <td id="T_7a1c7_row1_col0" class="data row1 col0" >GDP per capita</td>
#       <td id="T_7a1c7_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Exploratory Data Analysis Part One</div>

# %%
plt.style.use('fivethirtyeight')

# %%
life_exp_df.head()
# Out:
#        Country  Life Expectancy (years) - Men  \
# 0  Afghanistan                           60.6
# 1      Albania                           74.8
# 2      Algeria                           73.3
# 3      Andorra                           81.7
# 4       Angola                           58.1
#
#    Life Expectancy (years) - Women  Happiness Score  \
# 0                             68.2            3.794
# 1                             81.3            4.959
# 2                             78.9            5.605
# 3                             84.8            6.955
# 4                             65.6            4.105
#
#    Fertility Rate (births per woman)
# 0                                4.7
# 1                                1.7
# 2                                2.9
# 3                                1.4
# 4                                5.3

# %%
df1 = life_exp_df
# .sort_values('Happiness Score', ascending = False).head(144) 
# You can add this line of code at end of first line to sort values in chart below, it's optional and also you can use head function to specify values...

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Radial Bar Chart of Happiness Scores in Respective Countries</div>

# %%
# set figure size
plt.figure(figsize=(20,24))
ax = plt.subplot(111, polar=True)
plt.axis('off')


# Set the coordinates limits
upperLimit = 8
lowerLimit = 3

# Compute max and min in the dataset
max = df1['Happiness Score'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df1['Happiness Score'] + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df1.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df1.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="black",
    color="#472183",
)

# little space between the bar and the label
labelPadding = 0.2

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df1["Country"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    plt.rcParams["font.weight"] = 'bold'
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Bar Chart of Top 15 Countries with highest Fertility Rate (births per woman)</div>

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:150%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">The Top 15 Countries with the Highest Fertility Rates are almost all African nations that have endured constant economic and financial hardships. </div>

# %% [markdown]
# <center><img src="https://upload.wikimedia.org/wikipedia/en/thumb/f/f2/Aljazeera_eng.svg/1200px-Aljazeera_eng.svg.png"></center>
# <center><img src="https://i.postimg.cc/t4zCRVtS/niger.png"
#              style='border-radius:10px'></center>

# %%
palette = ["#590d22","#800f2f","#a4133c","#c9184a","#ff4d6d","#ff758f","#ff8fa3","#ffb3c1","#ffccd5","#fff0f3"]
top_df = df1.sort_values('Fertility Rate (births per woman)', ascending = False)
plt.subplots(figsize=(20,8))
p = sns.barplot(x=top_df["Country"].head(15),y=top_df["Fertility Rate (births per woman)"].head(15),palette=palette, saturation=1, edgecolor = "#1c1c1c", linewidth = 2)
p.axes.set_title("\nTop 15 Countries with highest Fertility Rate (births per woman)\n", fontsize=25)
plt.ylabel("Avg. Births Per Woman" , fontsize = 20)
plt.xlabel("\nCountry" , fontsize = 20)
plt.xticks(rotation = 90)
for container in p.containers:
    p.bar_label(container,label_type = "center", padding = 6, size = 15, color = "black",rotation = 90,
    bbox={"boxstyle": "round", "pad": 0.6, "facecolor": "#f08080", "edgecolor": "black", "alpha": 1})

sns.despine(left=True, bottom=True)
plt.show()

# %%
df2 = life_exp_df
# .sort_values('Life Expectancy (years) - Men', ascending = False).head(120)
# You can add this line of code at end of first line to sort values in chart below, it's optional and also you can use head function to specify values...

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Radial Bar Chart of Life Expectancy (years) - Men</div>

# %%
# set figure size
plt.figure(figsize=(20,24))
ax = plt.subplot(111, polar=True)
plt.axis('off')


# Set the coordinates limits
upperLimit = 85
lowerLimit = 51

# Compute max and min in the dataset
max = df2['Life Expectancy (years) - Men'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df2['Life Expectancy (years) - Men'] + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df2.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df2.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="black",
    color="#4B56D2",
)

# little space between the bar and the label
labelPadding = 0.5

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df2["Country"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    plt.rcParams["font.weight"] = 'bold'
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %%
df3 = life_exp_df
# .sort_values('Life Expectancy (years) - Women', ascending = False).head(120)
# You can add this line of code at end of first line to sort values in chart below, it's optional and also you can use head function to specify values...

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Radial Bar Chart of Life Expectancy (years) - Women</div>

# %%
# set figure size
plt.figure(figsize=(20,24))
ax = plt.subplot(111, polar=True)
plt.axis('off')


# Set the coordinates limits
upperLimit = 90
lowerLimit = 54

# Compute max and min in the dataset
max = df3['Life Expectancy (years) - Women'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df3['Life Expectancy (years) - Women'] + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df3.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df3.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="black",
    color="#FF597B",
)

# little space between the bar and the label
labelPadding = 0.5

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df3["Country"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    plt.rcParams["font.weight"] = 'bold'
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Scatter Plot Cross Life Expectancy Men and Women</div>

# %%
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
fig = px.scatter(df1, x="Life Expectancy (years) - Men", y="Life Expectancy (years) - Women", color="Happiness Score", size_max=35,
                 size='Happiness Score', template = 'plotly_white', hover_data=['Country', 'Life Expectancy (years) - Men', 'Life Expectancy (years) - Women', 'Happiness Score', 'Fertility Rate (births per woman)'],
                 title='Scatter Plot Cross Life Expectancy Men and Women')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <div style="padding:20px;color:white;margin:0;font-size:250%;text-align:left;display:fill;border-radius:5px;background-color:#2B2B2B;overflow:hidden;font-weight:500">Note: This is a Work in Progress.</div>
