# %% [markdown]
# <img src="https://www.we-explore.org/wp-content/uploads/2018/09/Explore_logo_bleu-slider.png"
#              style='border-radius:10px'>
# # <b>1 <span style='color:#D61C4E'>|</span> Explore Dataset using Functions</b>

# %% [markdown]
# ## <b>1.1 <span style='color:#D61C4E'>|</span> Defining Functions</b>

# %%
def import_data_analysis_libs():
    import os
    import warnings
    import pandas as pd
    import numpy as np 
    import matplotlib.pyplot as plt
    import seaborn as sns
    import plotly.io as pio
    
    print("Imported pandas as pd")
    print("Imported numpy as np")
    print("Imported matplotlib as plt")
    print("Imported seaborn as sns")
    print("Imported plotly as pio")   
    return os, warnings, pd, np, plt, sns, pio

# %%
def calculate_missing_percentage(df):
    """
    This function takes a Pandas DataFrame as input and returns a DataFrame showing the percentage of
    missing values in each column.
    """
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({'column_name': df.columns, 'percent_missing': percent_missing})
    missing_value_df = missing_value_df.sort_values('percent_missing', ascending=False)
    missing_value_df = missing_value_df.reset_index(drop=True)
    return missing_value_df

# %%
# Importing Libraries
os, warnings, pd, np, plt, sns, pio = import_data_analysis_libs()
# Out:
# Imported pandas as pd
# Imported numpy as np
# Imported matplotlib as plt
# Imported seaborn as sns
# Imported plotly as pio

# %% [markdown]
# ## <b>1.2 <span style='color:#D61C4E'>|</span> Load & Explore Dataset</b>
#
# - Country: The country to which the data belongs.
# - Year: The year in which the data was collected.
# - Status: Whether the country is classified as "Developing" or "Developed".
# - Life expectancy (men): The average life expectancy of men in that country for that year.
# - Life expectancy (women): The average life expectancy of women in that country for that year.
# - Adult Mortality (men): The mortality rate amongst adult men in that country for that year.
# - Adult Mortality (women): The mortality rate amongst adult women in that country for that year.
# - Infant deaths: The number of infant deaths in that country for that year.
# - Alcohol: Per capita alcohol consumption (in litres of pure alcohol) in that country for that year.
# - Percentage expenditure: Expenditure on health as a percentage of Gross Domestic Product per capita(%).
# - Hepatitis B (men): Hepatitis B vaccination coverage in men (%).
# - Hepatitis B (women): Hepatitis B vaccination coverage in women (%).
# - Measles: Number of reported cases of measles in that country for that year.
# - BMI: Average Body Mass Index of the country's population.
# - Under-five deaths: Number of deaths under five years old.
# - Polio: Polio (Pol3) immunization coverage among 1-year-olds (%).
# - Total expenditure: General government expenditure on health as a percentage of total government expenditure (%).
# - Diphtheria: Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%).
# - HIV/AIDS: Deaths per 1,000 live births HIV/AIDS (0-4 years).
# - GDP: Gross Domestic Product per capita (in USD).
# - Population: Population of the country.
# - thinness 1-19 years: Prevalence of thinness among children and adolescents for Age 10 to 19 (%).
# - thinness 5-9 years: Prevalence of thinness among children for Age 5 to 9(%).
# - Income composition of resources: Human Development Index in terms of income composition of resources (index ranging from 0 to 1).
# - Schooling: Number of years of Schooling (years).

# %%
pd.options.display.max_columns = 25 # Set Max columns to 25 so we can view all columns in pd dataframe
df = pd.read_csv('/kaggle/input/life-expectancy-data/Life Expectancy Data v2.csv')
df.head(5).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_77be0_row0_col1, #T_77be0_row0_col13, #T_77be0_row0_col20, #T_77be0_row0_col23, #T_77be0_row0_col24, #T_77be0_row1_col11, #T_77be0_row2_col3, #T_77be0_row2_col5, #T_77be0_row3_col4, #T_77be0_row3_col6, #T_77be0_row3_col9, #T_77be0_row3_col10, #T_77be0_row3_col16, #T_77be0_row3_col19, #T_77be0_row4_col7, #T_77be0_row4_col12, #T_77be0_row4_col14, #T_77be0_row4_col15, #T_77be0_row4_col17, #T_77be0_row4_col21, #T_77be0_row4_col22 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_77be0_row0_col3 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_77be0_row0_col4, #T_77be0_row0_col17, #T_77be0_row2_col1, #T_77be0_row2_col21, #T_77be0_row3_col24 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_77be0_row0_col5, #T_77be0_row2_col17 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# ...

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_3989c_row0_col0, #T_3989c_row0_col1, #T_3989c_row0_col2, #T_3989c_row0_col3, #T_3989c_row0_col4, #T_3989c_row0_col5, #T_3989c_row0_col6, #T_3989c_row0_col8, #T_3989c_row0_col9, #T_3989c_row0_col11, #T_3989c_row0_col12, #T_3989c_row0_col13, #T_3989c_row0_col14, #T_3989c_row0_col15, #T_3989c_row0_col16, #T_3989c_row0_col19, #T_3989c_row0_col20, #T_3989c_row0_col21, #T_3989c_row0_col22, #T_3989c_row7_col7, #T_3989c_row7_col10, #T_3989c_row7_col17, #T_3989c_row7_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3989c_row0_col7 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_3989c_row0_col10, #T_3989c_row1_col11, #T_3989c_row1_col12, #T_3989c_row3_col1, #T_3989c_row3_col2, #T_3989c_row3_col3, #T_3989c_row3_col4, #T_3989c_row5_col11, #T_3989c_row5_col17, #T_3989c_row6_col8, #T_3989c_row6_col9 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# ...

# %%
missing_values = calculate_missing_percentage(df)
missing_values.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_97b3c_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_97b3c_row1_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_97b3c_row2_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_97b3c_row3_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_97b3c_row4_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_97b3c_row5_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_97b3c_row6_col1, #T_97b3c_row7_col1, #T_97b3c_row8_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_97b3c_row9_col1, #T_97b3c_row10_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# ...

# %%
# Generate a custom color map
custom_cmap = sns.color_palette("magma")  # Replace "Blues" with your desired color scheme

# Plot null value heatmap with custom color map
sns.heatmap(df.isnull(), cmap=custom_cmap, cbar_kws={'label': 'Null Values'})

# Add a title
plt.title('Null Value Heatmap')

# Show the plot
plt.show()
